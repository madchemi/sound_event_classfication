# %%
# !pip install resampy
# Out:
# Collecting resampy
#   Downloading resampy-0.4.3-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from resampy) (1.26.4)
# Requirement already satisfied: numba>=0.53 in /usr/local/lib/python3.10/dist-packages (from resampy) (0.60.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.53->resampy) (0.43.0)
# Downloading resampy-0.4.3-py3-none-any.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 15.1 MB/s eta 0:00:00
# Installing collected packages: resampy
# Successfully installed resampy-0.4.3

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#pytorch
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
#데이터셋 로더
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
#음성파일 처리
import librosa
#기타
import numpy as np
# Out:
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold1/101415-3-0-2.wav
# (40, 174)
# array([[-5.2501501e+02, -5.1950610e+02, -5.1859204e+02, ...,
#         -3.8555713e+02, -3.0882330e+02,  0.0000000e+00],
#        [ 9.1998549e+00,  1.6759342e+01,  1.8103775e+01, ...,
#          1.4781575e+02,  1.3715564e+02,  0.0000000e+00],
#        [ 8.8354836e+00,  1.5750018e+01,  1.7259182e+01, ...,
#          4.9131630e+01,  3.1268047e+01,  0.0000000e+00],
#        ...,
#        [ 4.3308336e-01, -3.5409122e+00, -4.8356676e+00, ...,
#         -1.6279453e-01,  3.1506971e-01,  0.0000000e+00],
#        [ 4.4518343e-01, -3.2775073e+00, -4.6473131e+00, ...,
#          3.9355516e+00,  1.0171671e+00,  0.0000000e+00],
#        [ 3.5693711e-01, -2.9899294e+00, -4.4126091e+00, ...,
#          2.7583482e+00, -3.4802508e-01,  0.0000000e+00]], dtype=float32)

# %%
  padding = lambda a, i: a[:, 0:i] if a.shape[1] > i else np.hstack((a, np.zeros((a.shape[0], i-a.shape[1]))))

# %%
from pickle import TRUE
from tqdm import tqdm
# 전처리
from PIL import Image

# 0 에어컨
# 2 children_playing
# 3 dog_bark
# 4 drill
# 6 gunshot
# 7 jack hammer
# 9 street music
skip_class=['0', '2', '3', '4', '6', '7', '9']

def pre_progressing(sound_dir, image_dir):
  # 마지막에 /로 끝나게
  if image_dir[-1] != '/':
    image_dir.join('/')
  if sound_dir[-1] != '/':
    sound_dir.join('/')
  for filename in tqdm(os.listdir(sound_dir)):
    # print(filename)
    # 유니코드 정규화?
    # filename = normalize('NFC', filename)
    # wav 포맷 데이터만 사용
    if '.wav' not in filename:
      continue
    # 필요없는 클래스 스
    if filename.split('-')[1] in skip_class:
      continue
    wav, sr = librosa.load(sound_dir+filename, sr=16000)
    # 이미지 ndarray
    mfcc = librosa.feature.mfcc(y=wav, sr=sr, n_mfcc=100, n_fft=400, hop_length=160)
    # 패딩된 ndarray
    # 리사이즈 할거면 패딩 필요없음?
    padded_mfcc = padding(mfcc, 500)

    # 해당 이미지 새로 저장
    # img = Image.fromarray(padded_mfcc)
    img = Image.fromarray(mfcc)
    img = img.convert('L')
    # resize크기 적당히 조절
    img = img.resize([32,32])
    img.save(image_dir+filename.split('-')[1]+'/'+filename+'.jpg','JPEG')

# 돌리기 전에 폴더 비워둘것
# 클래스 빈 폴더 생성
for i in range(10):
  os.makedirs('/content/mount/MyDrive/image_set/'+str(i), exist_ok=True)
# 전처리 과정 수행
for i in range(10):
  pre_progressing('/content/mount/MyDrive/gist_공모전/archive-2/fold'+str(i+1)+'/', '/content/mount/MyDrive/image_set/')
# Out:
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold5/100032-3-0-0.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold5/100263-2-0-117.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold5/100263-2-0-121.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold5/100263-2-0-126.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold5/100263-2-0-137.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold5/100263-2-0-143.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold5/100263-2-0-161.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold5/100263-2-0-3.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold5/100263-2-0-36.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/100648-1-0-0.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/100648-1-1-0.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/100648-1-2-0.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/100648-1-3-0.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/100648-1-4-0.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold2/100652-3-0-0.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold2/100652-3-0-1.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold2/100652-3-0-2.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold2/100652-3-0-3.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/100795-3-0-0.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/100795-3-1-0.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/100795-3-1-1.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/100795-3-1-2.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold5/100852-0-0-0.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold5/100852-0-0-1.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold5/100852-0-0-10.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold5/100852-0-0-11.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold5/100852-0-0-12.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold5/100852-0-0-13.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold5/100852-0-0-14.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold5/100852-0-0-15.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold5/100852-0-0-16.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold5/100852-0-0-17.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold5/100852-0-0-18.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold5/100852-0-0-19.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold5/100852-0-0-2.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold5/100852-0-0-20.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold5/100852-0-0-21.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold5/100852-0-0-22.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold5/100852-0-0-23.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold5/100852-0-0-24.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold5/100852-0-0-25.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold5/100852-0-0-26.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold5/100852-0-0-27.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold5/100852-0-0-28.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold5/100852-0-0-29.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold5/100852-0-0-3.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold5/100852-0-0-30.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold5/100852-0-0-4.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold5/100852-0-0-5.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold5/100852-0-0-6.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold5/100852-0-0-7.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold5/100852-0-0-8.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold5/100852-0-0-9.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold6/101281-3-0-0.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold6/101281-3-0-14.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold6/101281-3-0-5.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/101382-2-0-10.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/101382-2-0-12.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/101382-2-0-20.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/101382-2-0-21.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/101382-2-0-29.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/101382-2-0-33.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/101382-2-0-42.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/101382-2-0-45.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold1/101415-3-0-2.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold1/101415-3-0-3.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold1/101415-3-0-8.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold9/101729-0-0-1.wav
# Error encountered while parsing file: /content/drive/MyDrive/gist_공모전/archive-2/fold9/101729-0-0-1.wav
# [Errno 2] No such file or directory: '/content/drive/MyDrive/gist_공모전/archive-2/fold9/101729-0-0-1.wav'
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold9/101729-0-0-11.wav
# Error encountered while parsing file: /content/drive/MyDrive/gist_공모전/archive-2/fold9/101729-0-0-11.wav
# [Errno 2] No such file or directory: '/content/drive/MyDrive/gist_공모전/archive-2/fold9/101729-0-0-11.wav'
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold9/101729-0-0-12.wav
# Error encountered while parsing file: /content/drive/MyDrive/gist_공모전/archive-2/fold9/101729-0-0-12.wav
# [Errno 2] No such file or directory: '/content/drive/MyDrive/gist_공모전/archive-2/fold9/101729-0-0-12.wav'
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold9/101729-0-0-13.wav
# Error encountered while parsing file: /content/drive/MyDrive/gist_공모전/archive-2/fold9/101729-0-0-13.wav
# [Errno 2] No such file or directory: '/content/drive/MyDrive/gist_공모전/archive-2/fold9/101729-0-0-13.wav'
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold9/101729-0-0-14.wav
# Error encountered while parsing file: /content/drive/MyDrive/gist_공모전/archive-2/fold9/101729-0-0-14.wav
# [Errno 2] No such file or directory: '/content/drive/MyDrive/gist_공모전/archive-2/fold9/101729-0-0-14.wav'
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold9/101729-0-0-16.wav
# Error encountered while parsing file: /content/drive/MyDrive/gist_공모전/archive-2/fold9/101729-0-0-16.wav
# [Errno 2] No such file or directory: '/content/drive/MyDrive/gist_공모전/archive-2/fold9/101729-0-0-16.wav'
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold9/101729-0-0-17.wav
# Error encountered while parsing file: /content/drive/MyDrive/gist_공모전/archive-2/fold9/101729-0-0-17.wav
# [Errno 2] No such file or directory: '/content/drive/MyDrive/gist_공모전/archive-2/fold9/101729-0-0-17.wav'
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold9/101729-0-0-18.wav
# Error encountered while parsing file: /content/drive/MyDrive/gist_공모전/archive-2/fold9/101729-0-0-18.wav
# [Errno 2] No such file or directory: '/content/drive/MyDrive/gist_공모전/archive-2/fold9/101729-0-0-18.wav'
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold9/101729-0-0-19.wav
# Error encountered while parsing file: /content/drive/MyDrive/gist_공모전/archive-2/fold9/101729-0-0-19.wav
# [Errno 2] No such file or directory: '/content/drive/MyDrive/gist_공모전/archive-2/fold9/101729-0-0
wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold6/98680-9-0-2.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold6/98680-9-0-3.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold6/98680-9-0-5.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold3/98681-9-0-0.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold3/98681-9-0-11.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold3/98681-9-0-12.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold3/98681-9-0-5.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold3/98681-9-0-6.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold3/98681-9-0-7.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold9/98859-7-0-0.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold9/98859-7-1-0.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold9/98859-7-2-0.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold9/98859-7-2-1.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold9/98859-7-2-2.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold9/98859-7-2-3.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold9/98859-7-2-4.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold9/98859-7-2-5.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold4/99157-9-0-10.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold4/99157-9-0-15.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold4/99157-9-0-16.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold4/99157-9-0-22.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold4/99157-9-0-24.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold4/99157-9-0-31.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold8/99179-9-0-12.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold8/99179-9-0-17.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold8/99179-9-0-19.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold8/99179-9-0-38.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold8/99179-9-0-53.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold8/99179-9-0-58.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold1/99180-9-0-0.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold1/99180-9-0-2.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold1/99180-9-0-36.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold1/99180-9-0-48.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold1/99180-9-0-49.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold1/99180-9-0-7.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold5/99185-3-0-0.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/99192-4-0-0.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/99192-4-0-1.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/99192-4-0-12.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/99192-4-0-15.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/99192-4-0-17.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/99192-4-0-18.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/99192-4-0-20.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/99192-4-0-24.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/99192-4-0-26.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/99192-4-0-27.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/99192-4-0-28.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/99192-4-0-3.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/99192-4-0-30.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/99192-4-0-32.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/99192-4-0-33.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/99192-4-0-38.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/99192-4-0-40.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/99192-4-0-41.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/99192-4-0-43.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/99192-4-0-47.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/99192-4-0-48.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/99192-4-0-49.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/99192-4-0-52.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/99192-4-0-53.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/99192-4-0-54.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/99192-4-0-55.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold10/99192-4-0-7.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold9/99500-2-0-1.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold9/99500-2-0-11.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold9/99500-2-0-2.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold9/99500-2-0-23.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold9/99500-2-0-29.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold9/99500-2-0-39.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold9/99500-2-0-41.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold9/99500-2-0-50.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold6/99710-9-0-11.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold6/99710-9-0-12.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold6/99710-9-0-16.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold6/99710-9-0-2.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold6/99710-9-0-5.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold6/99710-9-0-6.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold7/99812-1-0-0.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold7/99812-1-0-1.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold7/99812-1-0-2.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold7/99812-1-1-0.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold7/99812-1-2-0.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold7/99812-1-3-0.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold7/99812-1-4-0.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold7/99812-1-5-0.wav
# (40, 174)
# file name: /content/drive/MyDrive/gist_공모전/archive-2/fold7/99812-1-6-0.wav
# (40, 174)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, random_split

# 데이터로더
dataset = ImageFolder(root='/content/mount/MyDrive/image_set/',transform=transforms.Compose([transforms.ToTensor(),]))

train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size

train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

# 각각의 데이터셋에 대해 DataLoader 생성
train_data_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_data_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# %%
# 피클로 데이터 저장
featuresdf.to_pickle("featuresdf.pkl")

# 피클 데이터 로드
featuresdf = pd.read_pickle("featuresdf.pkl")

# %%
#GPT가 짠 코드
#resnet버전
import torch
import torch.nn as nn
import torch.nn.functional as F

class ResidualBlock(nn.Module):
    def __init__(self, filters_in, filters_out):
        super(ResidualBlock, self).__init__()
        self.conv1 = nn.Conv2d(filters_in, filters_in, kernel_size=1, stride=1, padding=0, bias=False)
        self.bn1 = nn.BatchNorm2d(filters_in)
        self.conv2 = nn.Conv2d(filters_in, filters_in, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(filters_in)
        self.conv3 = nn.Conv2d(filters_in, filters_out, kernel_size=1, stride=1, padding=0, bias=False)
        self.bn3 = nn.BatchNorm2d(filters_out)

        # Shortcut layer
        if filters_in != filters_out:
            self.shortcut = nn.Conv2d(filters_in, filters_out, kernel_size=1, stride=1, padding=0, bias=False)
        else:
            self.shortcut = None

    def forward(self, x):
        shortcut = x

        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))

        if self.shortcut is not None:
            shortcut = self.shortcut(x)

        out += shortcut
        out = F.relu(out)
        return out

class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()
        # Initial Conv Layer
        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(16)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)

        # Residual Blocks
        self.res_block1 = ResidualBlock(16, 32)
        self.res_block2 = ResidualBlock(32, 32)
        self.res_block3 = ResidualBlock(32, 64)
        self.res_block4 = ResidualBlock(64, 64)

        # Global Average Pooling
        self.global_pool = nn.AdaptiveAvgPool2d((1, 1))

        # Fully connected layers
        self.fc1 = nn.Linear(64, 32)
        self.fc2 = nn.Linear(32, 10)

        # Dropout
        self.dropout = nn.Dropout(0.5)

    def forward(self, x):
        # Initial Conv Layer
        x = F.relu(self.bn1(self.conv1(x)))
        x = self.pool(x)

        # Residual Blocks with Pooling
        x = self.res_block1(x)
        x = self.pool(x)
        x = self.res_block2(x)
        x = self.res_block3(x)
        x = self.pool(x)
        x = self.res_block4(x)

        # Global Average Pooling
        x = self.global_pool(x)
        x = x.view(x.size(0), -1)  # Flatten

        # Fully connected layers
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)

        return x

# Model instantiation
model = CNNModel()

# Loss and Optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

# To check the model summary and architecture, we can print it.
print(model)

# %%
# 성능 평가 함수 (검증 또는 테스트 데이터로 성능 확인)
def evaluate(model, data_loader, criterion):
    model.eval()  # 모델을 평가 모드로 전환
    total_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():  # 평가 시에는 역전파 불필요
        for inputs, labels in data_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = model(inputs)
            loss = criterion(outputs, labels)

            total_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100 * correct / total
    avg_loss = total_loss / len(data_loader)

    print(f'Validation Loss: {avg_loss:.4f}, Validation Accuracy: {accuracy:.2f}%')
    return avg_loss, accuracy

evaluate(model, val_data_loader, criterion)# 성능 평가 함수 (검증 또는 테스트 데이터로 성능 확인)
def evaluate(model, data_loader, criterion):
    model.eval()  # 모델을 평가 모드로 전환
    total_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():  # 평가 시에는 역전파 불필요
        for inputs, labels in data_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = model(inputs)
            loss = criterion(outputs, labels)

            total_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100 * correct / total
    avg_loss = total_loss / len(data_loader)

    print(f'Validation Loss: {avg_loss:.4f}, Validation Accuracy: {accuracy:.2f}%')
    return avg_loss, accuracy

evaluate(model, val_data_loader, criterion)
